# %% [markdown]
# # Regime Detection
#
# Load ETF OHLCV data and fit the no-lookahead rolling regime model.

# %%
from regime_lab import fit_regime_model, load_market_data

market = load_market_data('../examples/sample_market_prices.csv')
result = fit_regime_model(market, n_regimes=3, lookback=20, min_train=30)
result.regimes.tail()
